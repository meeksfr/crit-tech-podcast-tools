# %%
pip install -U openai-whisper
# Out:
# Collecting openai-whisper
#   Downloading openai-whisper-20230314.tar.gz (792 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.9/792.9 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.0.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Collecting tiktoken==0.3.1 (from openai-whisper)
#   Downloading tiktoken-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.6 MB/s eta 0:00:00
# Collecting ffmpeg-python==0.2.0 (from openai-whisper)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python==0.2.0->openai-whisper) (0.18.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.3.1->openai-whisper) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.3.1->openai-whisper) (2.31.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper) (3.27.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper) (3.12.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper) (16.0.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=796907 sha256=c955e0c790398a94192a3509c2fb7d690025de077e4bfd2509a2d3b67018beaf
#   Stored in directory: /root/.cache/pip/wheels/b2/13/5f/fe8245f6dc59df505879da4b2129932e342f02a80e6b87f27d
# Successfully built openai-whisper
# Installing collected packages: ffmpeg-python, tiktoken, openai-whisper
# Successfully installed ffmpeg-python-0.2.0 openai-whisper-20230314 tiktoken-0.3.1

# %%
pip install ffmpeg-python
# Out:
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (0.18.3)

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("/content/s3e5p3.mp3")
print(result["text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  This is a good question and it's a hard question. I mean, you might say that the questions of legitimacy are core to the gender binary in some ways, right? In the way that masculine and feminine have been defined in Western culture for a long time now and how femininity tends to be associated with, for instance, passivity and emotionality. But within games, I think it's important to note that it was like a historical moment where these definitions of what a gamer is and what a game designer. There was a moment where it happened, right? It wasn't intrinsic from the very beginning of games history, right? If you look at, for instance, interactive fiction games, which were huge at a certain point in the history of games, there was lots of participation of women in particular and well-known women in there. But it was a moment, I think, of the professionalization of the video game industry where we saw a real commitment to a kind of sure-bet audience, that audience of the hardcore gamer, this typically young white male player that was seen as definitely going to be buying these games, definitely going to be investing lots of hours of them, definitely wanting to buy sequels and maintain a connection to a particular universe of games. And that goes with the kind of growth in profitability of the game's industry and an increasing risk of version within the game's industry. And we see the traces of that in endless cycles of FIFA and Call of Duty. And that's fine. Like I can understand why people enjoy playing those games, but it does suggest a sort of stagnation within the games industry that is counter to the possibilities of innovation, considering how many incredibly creative and talented people work there. It is in some ways about industrial norms. And that is very much connected to gender and the identity of who's the gamer and who's the person who's going to be making our games, because it was so invested in that one vision of the player for such a long time. And that configuration of the hardcore as being about particular investments in knowledge, in time, in difficulty, in certain kinds of language and spaces of culture that has made everything else that's happened. Alternative game spaces, alternative games, alternative game makers, alternative game players. There's more of that than there is the hardcore in many ways, but that investment in the hardcore is so longstanding in a risk-adverse place that it is really hard to shake. Everything becomes defined relative to that particular one place. And we must admit that there are very vocal people that use social media to harass all kinds of people, including people who work in the games industry, when these norms are seen as being somehow challenged or bypassed. So it's not just the industry being worried about their profit margin. It's also a sort of vocal sector of games culture that really perpetuates this really strongly, that contributed to things like harassment campaigns online and regular harassment campaigns against people who make games to this day. I can't imagine what it's like to work in the games industry. Individual people don't have a lot of say over what's legitimate in games. It's at the upper level that I think they're still resistance based on my interviews with people who work in the games industry. You hear a lot about organizations having women in games groups, or LGBT groups within the workplace. There's a lot of acceptance and a lot of interest in diversity, but they're fighting against the leadership, the management level, who have more of an interest maybe in financial questions. As a feminist and someone who's interested in political economy, you do spend a lot of time outlining structural issues, and they are powerful. And those are important things to keep in mind when we're talking about how to address issues of diversity inclusion. But I would say my answer is yes. There are ways to do this. And since Twine's Revolution was published, we do see sh ...

# %%
#open text file
text_file = open("/content/transcript.txt", "w")

#write string to file
text_file.write(result["text"])

#close file
text_file.close()

# %%
a = 10

# %%
print(a)
# Out:
# 10
